# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
data = pd.read_csv(r'/content/wage_rates_by_education.csv')

# %% [markdown]
# # Dataset

# %%
data
# Out:
#         YEAR         Geography              Type of work  \
# 0       1997            Canada  Both full- and part-time
# 1       1997            Canada  Both full- and part-time
# 2       1997            Canada  Both full- and part-time
# 3       1997            Canada  Both full- and part-time
# 4       1997            Canada  Both full- and part-time
# ...      ...               ...                       ...
# 425035  2019  British Columbia                Part-time
# 425036  2019  British Columbia                Part-time
# 425037  2019  British Columbia                Part-time
# 425038  2019  British Columbia                Part-time
# 425039  2019  British Columbia                Part-time
#
#                           Wages              Education level  \
# 0               Total employees  Total, all education levels
# 1               Total employees  Total, all education levels
# 2               Total employees  Total, all education levels
# 3               Total employees  Total, all education levels
# 4               Total employees  Total, all education levels
# ...                         ...                          ...
# 425035  Median weekly wage rate          No PSE  (0,1,2,3,4)
# 425036  Median weekly wage rate          No PSE  (0,1,2,3,4)
# 425037  Median weekly wage rate          No PSE  (0,1,2,3,4)
# 425038  Median weekly wage rate          No PSE  (0,1,2,3,4)
# 425039  Median weekly wage rate          No PSE  (0,1,2,3,4)
#
#                  Age group  Both Sexes    Male    Female
# 0       15 years and over     11364.50  5954.5    5410.0
# 1              15-24 years     1877.80   983.1     894.7
# 2              20-34 years     4274.90  2244.3    2030.6
# 3        25 years and over     9486.70  4971.4    4515.3
# 4              25-34 years     3047.90  1602.2    1445.7
# ...                    ...         ...     ...       ...
# 425035   25 years and over      331.25   320.0     336.0
# 425036         25-34 years      308.00   300.0     316.8
# 425037         25-54 years      346.25   320.0     360.0
# 425038         25-64 years      346.20   336.0     348.3
# 425039   55 years and over      300.00   324.0     300.0
#
# [425040 rows x 9 columns]

# %%
data.columns
# Out:
# Index(['YEAR', 'Geography', 'Type of work', 'Wages', 'Education level',
#        'Age group', 'Both Sexes', '  Male', '  Female'],
#       dtype='object')

# %%
data.groupby('Education level') ['Both Sexes'] .sum()
# Out:
# Education level
#       Above bachelor's degree                         9981586.91
#       Bachelor's degree                               9816962.08
#     Community college, CEGEP                          8436336.44
#     Trade certificate or diploma                      8008981.03
#     University certificate below bachelors degree     7171511.98
#    0 - 8  years                                       4725853.73
#    High school graduate                               7232588.79
#    Post-secondary certificate or diploma              9343019.02
#    Some high school                                   6010343.19
#    Some post-secondary                                6457850.75
#    University degree                                 10694383.42
# No PSE  (0,1,2,3,4)                                   8006784.25
# PSE  (5,6,7,8,9))                                    11418359.37
# Total, all education levels                          12543138.79
# Name: Both Sexes, dtype: float64

# %% [markdown]
# ### Calculate the average weekly wage of Canadians with different education levels

# %%
data.groupby('Education level') ['Both Sexes'] .mean()
# Out:
# Education level
#       Above bachelor's degree                        328.774272
#       Bachelor's degree                              323.351847
#     Community college, CEGEP                         277.876694
#     Trade certificate or diploma                     263.800429
#     University certificate below bachelors degree    236.215810
#    0 - 8  years                                      155.660531
#    High school graduate                              238.227562
#    Post-secondary certificate or diploma             307.741074
#    Some high school                                  197.969143
#    Some post-secondary                               212.709181
#    University degree                                 352.252418
# No PSE  (0,1,2,3,4)                                  263.728071
# PSE  (5,6,7,8,9))                                    376.098793
# Total, all education levels                          413.146864
# Name: Both Sexes, dtype: float64

# %%
data.groupby('Education level') [['  Male','  Female', 'Both Sexes']].mean()
# Out:
#                                                          Male      Female  \
# Education level
#       Above bachelor's degree                      314.856389  291.795700
#       Bachelor's degree                            307.275986  288.194034
#     Community college, CEGEP                       271.178771  239.610122
#     Trade certificate or diploma                   273.003701  189.684680
#     University certificate below bachelors degree  218.543975  198.060774
#    0 - 8  years                                    160.638497   89.253663
#    High school graduate                            243.918645  188.733013
#    Post-secondary certificate or diploma           300.160718  244.780663
#    Some high school                                209.951107  142.889875
#    Some post-secondary                             219.324243  176.450980
#    University degree                               334.537700  309.438453
# No PSE  (0,1,2,3,4)                                257.175662  196.064736
# PSE  (5,6,7,8,9))                                  342.543482  295.320012
# Total, all education levels                        348.462211  296.690446
#
#                                                    Both Sexes
# Education level
#       Above bachelor's degree                      328.774272
#       Bachelor's degree                            323.351847
#     Community college, CEGEP                       277.876694
#     Trade certificate or diploma                   263.800429
#     University certificate below bachelors degree  236.215810
#    0 - 8  years                                    155.660531
#    High school graduate                            238.227562
#    Post-secondary certificate or diploma           307.741074
#    Some high school                                197.969143
#    Some post-secondary                             212.709181
#    University degree                               352.252418
# No PSE  (0,1,2,3,4)                                263.728071
# PSE  (5,6,7,8,9))                                  376.098793
# Total, all education levels                        413.146864

# %%
sns.barplot(x='Both Sexes', y='Education level', color='blue', data=data)
# Out:
# <Axes: xlabel='Both Sexes', ylabel='Education level'>

# %% [markdown]
# ### Distribute the average weekly wage data by Type of work class and present it in a chart.

# %%
data.groupby('Type of work') [['  Male','  Female', 'Both Sexes']] .mean()
# Out:
#                                 Male      Female  Both Sexes
# Type of work
#    Full-time              375.287157  295.172584  375.488423
#    Part-time               79.092782  107.958801  114.359609
# Both full- and part-time  360.242437  271.218718  356.056116

# %%
sns.displot(data=data, x='  Male', hue= 'Type of work', kind = 'kde')

# %%
sns.displot(data=data, x='  Female', hue= 'Type of work', kind = 'kde')

# %%
sns.displot(data=data, x='Both Sexes', hue= 'Type of work', kind = 'kde')

# %% [markdown]
# ### Distribute Wages data into all avaliable classes.

# %%
data.groupby('Wages') [['  Male','  Female', 'Both Sexes']].mean()
# Out:
#                                 Male      Female  Both Sexes
# Wages
# Average hourly wage rate   17.668114   16.256290   18.029631
# Average weekly wage rate  627.870053  507.648147  597.360235
# Median hourly wage rate    16.132956   14.892383   16.414029
# Median weekly wage rate   579.248499  470.598207  546.667754
# Total employees           116.784338  114.521812  231.368598

# %%
sns.displot(data=data, x='Both Sexes', hue= 'Wages', kind = 'ecdf')

# %%
sns.displot(data=data, x='  Male', hue= 'Wages', kind = 'ecdf')

# %%
sns.displot(data=data, x='  Female', hue= 'Wages', kind = 'ecdf')

# %% [markdown]
# ### Distribute average weekly wage by different classes of age group.

# %%
data.groupby('Age group')  [['  Male','  Female', 'Both Sexes']].mean()
# Out:
#                           Male      Female  Both Sexes
# Age group
# 15 years and over   315.267005  261.408302  335.902278
# 15-24 years         134.831498  119.416227  145.295103
# 20-34 years         232.531326  196.100085  240.329704
# 25 years and over   326.925784  269.911213  341.218973
# 25-34 years         240.844618  204.594069  250.641141
# 25-54 years         315.098251  262.315385  328.882831
# 25-64 years         326.678772  269.877510  341.037218
# 55 years and over   280.149080  214.644152  272.437149

# %%
sns.barplot(x='  Male', y='Age group', data=data)
# Out:
# <Axes: xlabel='  Male', ylabel='Age group'>

# %%
sns.barplot(x='  Female', y='Age group', data=data)
# Out:
# <Axes: xlabel='  Female', ylabel='Age group'>

# %%
sns.barplot(x='Both Sexes', y='Age group', data=data)
# Out:
# <Axes: xlabel='Both Sexes', ylabel='Age group'>

# %% [markdown]
# ###  Find out the correlation between Year, Both Sexes, Male and Female

# %%
data.corr()
# Out:
# <ipython-input-33-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                 YEAR  Both Sexes      Male    Female
# YEAR        1.000000    0.092515  0.103147  0.116961
# Both Sexes  0.092515    1.000000  0.910766  0.936250
#   Male      0.103147    0.910766  1.000000  0.958442
#   Female    0.116961    0.936250  0.958442  1.000000

# %% [markdown]
# #### Find unique and nunique values in Education level column.

# %%
data['Education level'].unique()
# Out:
# array(['Total, all education levels', '   0 - 8  years',
#        '   Some high school', '   High school graduate',
#        '   Some post-secondary',
#        '   Post-secondary certificate or diploma',
#        '    Trade certificate or diploma', '    Community college, CEGEP',
#        '    University certificate below bachelors degree',
#        '   University degree', "      Bachelor's degree",
#        "      Above bachelor's degree", 'PSE  (5,6,7,8,9))',
#        'No PSE  (0,1,2,3,4)'], dtype=object)

# %%
data['Education level'].nunique()
# Out:
# 14

# %% [markdown]
# ### Apply iloc on two different tables and then merge the tables together by applying the appropriate function.

# %%
data1 = data.iloc[ : , 3:5]

# %%
data2 = data.iloc[ : , 7:9 ]

# %%
pd.concat([data1,data2], axis = 1)
# Out:
#                           Wages              Education level    Male    Female
# 0               Total employees  Total, all education levels  5954.5    5410.0
# 1               Total employees  Total, all education levels   983.1     894.7
# 2               Total employees  Total, all education levels  2244.3    2030.6
# 3               Total employees  Total, all education levels  4971.4    4515.3
# 4               Total employees  Total, all education levels  1602.2    1445.7
# ...                         ...                          ...     ...       ...
# 425035  Median weekly wage rate          No PSE  (0,1,2,3,4)   320.0     336.0
# 425036  Median weekly wage rate          No PSE  (0,1,2,3,4)   300.0     316.8
# 425037  Median weekly wage rate          No PSE  (0,1,2,3,4)   320.0     360.0
# 425038  Median weekly wage rate          No PSE  (0,1,2,3,4)   336.0     348.3
# 425039  Median weekly wage rate          No PSE  (0,1,2,3,4)   324.0     300.0
#
# [425040 rows x 4 columns]

# %% [markdown]
# ### Prepare the pivot table for Wages, Education level and Age group cloumns.

# %%
pd.pivot_table(data, values= 'Both Sexes', index= ['Wages', 'Education level'], columns= ['Age group'], aggfunc=np.mean)
# Out:
# Age group                                                                   15 years and over   \
# Wages                    Education level
# Average hourly wage rate       Above bachelor's degree                               28.718327
#                                Bachelor's degree                                     24.259157
#                              Community college, CEGEP                                19.485310
#                              Trade certificate or diploma                            18.886733
#                              University certificate below bachelors degree           20.052912
# ...                                                                                        ...
# Total employees             Some post-secondary                                     142.076416
#                             University degree                                       410.603953
#                          No PSE  (0,1,2,3,4)                                        689.453360
#                          PSE  (5,6,7,8,9))                                         1004.494335
#                          Total, all education levels                               1693.948353
#
# Age group                                                                   15-24 years  \
# Wages                    Education level
# Average hourly wage rate       Above bachelor's degree                         3.769051
#                                Bachelor's degree                              14.089960
#                              Community college, CEGEP                         12.802411
#                              Trade certificate or diploma                     11.805534
#                              University certificate below bachelors degree     8.265665
# ...                                                                                 ...
# Total employees             Some post-secondary                               58.423715
#                             University degree                                 21.430698
#                          No PSE  (0,1,2,3,4)                                 198.415020
#                          PSE  (5,6,7,8,9))                                    82.654941
#                          Total, all education levels                         281.069960
#
# Age group                                                                   20-34 years  \
# Wages                    Education level
# Average hourly wage rate       Above bachelor's degree                        20.970830
#                                Bachelor's degree                              20.656904
#                              Community college, CEGEP                         16.924005
#                              Trade certificate or diploma                     16.390487
#                              University certificate below bachelors degree    14.982925
# ...                                                                                 ...
# Total employees             Some post-secondary                               66.482609
#                             University degree                                148.185244
#                          No PSE  (0,1,2,3,4)                                 217.239789
#                          PSE  (5,6,7,8,9))                                   354.593281
#                          Total, all education levels                         571.831884
#
# Age group                                                                   25 years and over  \
# Wages                    Education level
# Average hourly wage rate       Above bachelor's degree                              28.940053
#                                Bachelor's degree                                    25.139328
#                              Community college, CEGEP                               20.278972
#                              Trade certificate or diploma                           19.416877
#                              University certificate below bachelors degree          20.995231
# ...                                                                                       ...
# Total employees             Some post-secondary                                     83.652833
#                             University degree                                      389.145191
#                          No PSE  (0,1,2,3,4)                                       491.040975
#                          PSE  (5,6,7,8,9))                                         921.840448
#                          Total, all education levels                              1412.878788
#
# Age group                                                                   25-34 years  \
# Wages                    Education level
# Average hourly wage rate       Above bachelor's degree                        21.279196
#                                Bachelor's degree                              21.936957
#                              Community college, CEGEP                         18.300158
#                              Trade certificate or diploma                     17.079789
#                              University certificate below bachelors degree    15.031080
# ...                                                                                 ...
# Total employees             Some post-secondary                               27.497892
#                             University degree                                126.845323
#                          No PSE  (0,1,2,3,4)                                 116.850461
#                          PSE  (5,6,7,8,9))                                   276.542292
#                          Total, all education levels                         393.393939
#
# Age group                                                                   25-54 years  \
# Wages                    Education level
# Average hourly wage rate       Above bachelor's degree                        27.813966
#                                Bachelor's degree                              24.982530
#                              Community college, CEGEP                         20.131884
#                              Trade certificate or diploma                     19.274111
#                              University certificate below bachelors degree    20.494769
# ...                                                                                 ...
# Total employees             Some post-secondary                               71.633070
#                             University degree                                338.301449
#                          No PSE  (0,1,2,3,4)                                 390.756126
#                          PSE  (5,6,7,8,9))                                   789.788933
#                          Total, all education levels                        1180.544796
#
# Age group                                                                   25-64 years  \
# Wages                    Education level
# Average hourly wage rate       Above bachelor's degree                        28.799947
#                                Bachelor's degree                              25.184611
#                              Community college, CEGEP                         20.313386
#                              Trade certificate or diploma                     19.499275
#                              University certificate below bachelors degree    20.969947
# ...                                                                                 ...
# Total employees             Some post-secondary                               82.137154
#                             University degree                                382.578920
#                          No PSE  (0,1,2,3,4)                                 477.291700
#                          PSE  (5,6,7,8,9))                                   905.848221
#                          Total, all education levels                        1383.137022
#
# Age group                                                                   55 years and over
# Wages                    Education level
# Average hourly wage rate       Above bachelor's degree                              28.450909
#                                Bachelor's degree                                    24.823663
#                              Community college, CEGEP                               20.739104
#                              Trade certificate or diploma                           19.027101
#                              University certificate below bachelors degree          18.068735
# ...                                                                                       ...
# Total employees             Some post-secondary                                     11.966008
#                             University degree                                       50.836759
#                          No PSE  (0,1,2,3,4)                                       100.284585
#                          PSE  (5,6,7,8,9))                                         132.048485
#                          Total, all education levels                               232.334783
#
# [70 rows x 8 columns]

# %%
pivm=pd.pivot_table(data, values= ['  Male','  Female'], index= ['Wages', 'Education level'], columns= ['Age group'], aggfunc=np.mean)

# %% [markdown]
# ### Prepare the pivot table and illustrate the different wages by Education level.

# %%
pd.pivot_table(data, values= ['Both Sexes'], index= ['Education level'], columns= ['Wages'], aggfunc=np.mean)
# Out:
#                                                                 Both Sexes  \
# Wages                                             Average hourly wage rate
# Education level
#       Above bachelor's degree                                    23.592785
#       Bachelor's degree                                          22.634139
#     Community college, CEGEP                                     18.621904
#     Trade certificate or diploma                                 17.672488
#     University certificate below bachelors degree                17.357658
#    0 - 8  years                                                  10.945410
#    High school graduate                                          15.534292
#    Post-secondary certificate or diploma                         18.635303
#    Some high school                                              13.866680
#    Some post-secondary                                           15.589496
#    University degree                                             23.762334
# No PSE  (0,1,2,3,4)                                              15.194875
# PSE  (5,6,7,8,9))                                                20.633406
# Total, all education levels                                      18.374061
#
#                                                                             \
# Wages                                             Average weekly wage rate
# Education level
#       Above bachelor's degree                                   782.485665
#       Bachelor's degree                                         727.861151
#     Community college, CEGEP                                    605.148412
#     Trade certificate or diploma                                615.312357
#     University certificate below bachelors degree               586.201825
#    0 - 8  years                                                 389.087067
#    High school graduate                                         518.258277
#    Post-secondary certificate or diploma                        616.721604
#    Some high school                                             468.975492
#    Some post-secondary                                          509.028165
#    University degree                                            765.535316
# No PSE  (0,1,2,3,4)                                             502.230988
# PSE  (5,6,7,8,9))                                               673.812153
# Total, all education levels                                     602.384811
#
#                                                                            \
# Wages                                             Median hourly wage rate
# Education level
#       Above bachelor's degree                                   22.472367
#       Bachelor's degree                                         20.994094
#     Community college, CEGEP                                    16.880166
#     Trade certificate or diploma                                16.294529
#     University certificate below bachelors degree               15.813556
#    0 - 8  years                                                  9.837200
#    High school graduate                                         13.960687
#    Post-secondary certificate or diploma                        16.925186
#    Some high school                                             12.481891
#    Some post-secondary                                          13.916089
#    University degree                                            22.100451
# No PSE  (0,1,2,3,4)                                             13.602795
# PSE  (5,6,7,8,9))                                               18.455909
# Total, all education levels                                     16.061492
#
#                                                                            \
# Wages                                             Median weekly wage rate
# Education level
#       Above bachelor's degree                                  746.531283
#       Bachelor's degree                                        680.631265
#     Community college, CEGEP                                   549.618068
#     Trade certificate or diploma                               568.677317
#     University certificate below bachelors degree              536.955944
#    0 - 8  years                                                349.716477
#    High school graduate                                        469.116884
#    Post-secondary certificate or diploma                       561.442103
#    Some high school                                            420.424881
#    Some post-secondary                                         457.028445
#    University degree                                           716.373048
# No PSE  (0,1,2,3,4)                                            452.445198
# PSE  (5,6,7,8,9))                                              609.116133
# Total, all education levels                                    535.271515
#
#
# Wages                                             Total employees
# Education level
#       Above bachelor's degree                           68.789262
#       Bachelor's degree                                164.638587
#     Community college, CEGEP                           199.114921
#     Trade certificate or diploma                       101.045455
#     University certificate below bachelors degree       24.750066
#    0 - 8  years                                         18.716502
#    High school graduate                                174.267671
#    Post-secondary certificate or diploma               324.981176
#    Some high school                                     74.096772
#    Some post-secondary                                  67.983712
#    University degree                                   233.490942
# No PSE  (0,1,2,3,4)                                    335.166502
# PSE  (5,6,7,8,9))                                      558.476367
# Total, all education levels                            893.642441

# %%
 pd.pivot_table(data, values= ['  Male','  Female'], index= ['Education level'], columns= ['Wages'], aggfunc=np.mean)
# Out:
#                                                                     Female  \
# Wages                                             Average hourly wage rate
# Education level
#       Above bachelor's degree                                    21.358605
#       Bachelor's degree                                          21.537037
#     Community college, CEGEP                                     17.622327
#     Trade certificate or diploma                                 14.579638
#     University certificate below bachelors degree                15.227574
#    0 - 8  years                                                   7.049868
#    High school graduate                                          14.040695
#    Post-secondary certificate or diploma                         17.322469
#    Some high school                                              11.510512
#    Some post-secondary                                           14.009190
#    University degree                                             22.597640
# No PSE  (0,1,2,3,4)                                              13.799071
# PSE  (5,6,7,8,9))                                                19.553837
# Total, all education levels                                      17.379601
#
#                                                                             \
# Wages                                             Average weekly wage rate
# Education level
#       Above bachelor's degree                                   700.293533
#       Bachelor's degree                                         671.530450
#     Community college, CEGEP                                    545.650922
#     Trade certificate or diploma                                460.350535
#     University certificate below bachelors degree               491.315229
#    0 - 8  years                                                 222.456782
#    High school graduate                                         434.500731
#    Post-secondary certificate or diploma                        535.558422
#    Some high school                                             346.242372
#    Some post-secondary                                          429.413086
#    University degree                                            706.971617
# No PSE  (0,1,2,3,4)                                             419.381723
# PSE  (5,6,7,8,9))                                               606.911057
# Total, all education levels                                     536.497597
#
#                                                                            \
# Wages                                             Median hourly wage rate
# Education level
#       Above bachelor's degree                                   20.777475
#       Bachelor's degree                                         20.240219
#     Community college, CEGEP                                    16.109704
#     Trade certificate or diploma                                13.412612
#     University certificate below bachelors degree               13.969114
#    0 - 8  years                                                  6.278923
#    High school graduate                                         12.676126
#    Post-secondary certificate or diploma                        15.774272
#    Some high school                                             10.343129
#    Some post-secondary                                          12.663095
#    University degree                                            21.334643
# No PSE  (0,1,2,3,4)                                             12.333742
# PSE  (5,6,7,8,9))                                               17.425952
# Total, all education levels                                     15.154353
#
#                                                                            \
# Wages                                             Median weekly wage rate
# Education level
#       Above bachelor's degree                                  682.643915
#       Bachelor's degree                                        637.229840
#     Community college, CEGEP                                   504.463473
#     Trade certificate or diploma                               426.483363
#     University certificate below bachelors degree              456.094473
#    0 - 8  years                                                203.440548
#    High school graduate                                        399.931141
#    Post-secondary certificate or diploma                       493.625341
#    Some high school                                            316.225069
#    Some post-secondary                                         392.867749
#    University degree                                           671.871024
# No PSE  (0,1,2,3,4)                                            381.640402
# PSE  (5,6,7,8,9))                                              546.658207
# Total, all education levels                                    475.200357
#
#                                                                    \
# Wages                                             Total employees
# Education level
#       Above bachelor's degree                           33.904974
#       Bachelor's degree                                 90.432625
#     Community college, CEGEP                           114.204183
#     Trade certificate or diploma                        33.597250
#     University certificate below bachelors degree       13.697480
#    0 - 8  years                                          7.042194
#    High school graduate                                 82.516370
#    Post-secondary certificate or diploma               161.622810
#    Some high school                                     30.128294
#    Some post-secondary                                  33.301779
#    University degree                                   124.417342
# No PSE  (0,1,2,3,4)                                    153.168742
# PSE  (5,6,7,8,9))                                      286.051005
# Total, all education levels                            439.220323
#
#                                                                       Male  \
# Wages                                             Average hourly wage rate
# Education level
#       Above bachelor's degree                                    21.527859
#       Bachelor's degree                                          21.238798
#     Community college, CEGEP                                     17.775878
#     Trade certificate or diploma                                 17.491311
#     University certificate below bachelors degree                14.444748
#    0 - 8  years                                                  10.300919
#    High school graduate                                          16.151606
#    Post-secondary certificate or diploma                         19.057273
#    Some high school                                              14.012828
#    Some post-secondary                                           15.398580
#    University degree                                             23.118426
# No PSE  (0,1,2,3,4)                                              16.183878
# PSE  (5,6,7,8,9))                                                21.398780
# Total, all education levels                                      19.252717
#
#                                                                             \
# Wages                                             Average weekly wage rate
# Education level
#       Above bachelor's degree                                   767.813165
#       Bachelor's degree                                         736.007523
#     Community college, CEGEP                                    643.152457
#     Trade certificate or diploma                                652.176069
#     University certificate below bachelors degree               545.710529
#    0 - 8  years                                                 401.870945
#    High school graduate                                         574.110181
#    Post-secondary certificate or diploma                        675.209419
#    Some high school                                             512.158722
#    Some post-secondary                                          542.082157
#    University degree                                            786.957543
# No PSE  (0,1,2,3,4)                                             561.979998
# PSE  (5,6,7,8,9))                                               731.999560
# Total, all education levels                                     658.952469
#
#                                                                            \
# Wages                                             Median hourly wage rate
# Education level
#       Above bachelor's degree                                   20.391052
#       Bachelor's degree                                         19.501565
#     Community college, CEGEP                                    16.260893
#     Trade certificate or diploma                                16.345349
#     University certificate below bachelors degree               13.348645
#    0 - 8  years                                                  9.495764
#    High school graduate                                         14.561963
#    Post-secondary certificate or diploma                        17.483664
#    Some high school                                             12.850730
#    Some post-secondary                                          13.783832
#    University degree                                            21.230479
# No PSE  (0,1,2,3,4)                                             14.560089
# PSE  (5,6,7,8,9))                                               19.150996
# Total, all education levels                                     16.896357
#
#                                                                            \
# Wages                                             Median weekly wage rate
# Education level
#       Above bachelor's degree                                  729.778720
#       Bachelor's degree                                        685.490260
#     Community college, CEGEP                                   593.852849
#     Trade certificate or diploma                               611.633248
#     University certificate below bachelors degree              508.335716
#    0 - 8  years                                                370.021989
#    High school graduate                                        523.042861
#    Post-secondary certificate or diploma                       625.716525
#    Some high school                                            466.819437
#    Some post-secondary                                         490.729503
#    University degree                                           732.356130
# No PSE  (0,1,2,3,4)                                            511.163141
# PSE  (5,6,7,8,9))                                              667.750980
# Total, all education levels                                    592.787625
#
#
# Wages                                             Total employees
# Education level
#       Above bachelor's degree                           34.771146
#       Bachelor's degree                                 74.141782
#     Community college, CEGEP                            84.851779
#     Trade certificate or diploma                        67.372530
#     University certificate below bachelors degree       10.880237
#    0 - 8  years                                         11.502866
#    High school graduate                                 91.726614
#    Post-secondary certificate or diploma               163.336709
#    Some high school                                     43.913818
#    Some post-secondary                                  34.627141
#    University degree                                   109.025922
# No PSE  (0,1,2,3,4)                                    181.991206
# PSE  (5,6,7,8,9))                                      272.417095
# Total, all education levels                            454.421887

# %% [markdown]
# ### Prepare the pivot table and illustrate the maximum and average wages by Education level.

# %%
piv=pd.pivot_table(data, values= ['Both Sexes'], index= ['Education level'], columns= ['Wages'], aggfunc={ 'Both Sexes':np.mean,
                       'Both Sexes':[ max,np.mean]})
pivM=pd.pivot_table(data, values= ['  Male'], index= ['Education level'], columns= ['Wages'], aggfunc={ '  Male':np.mean,
                       '  Male':[ max,np.mean]})
pivF=pd.pivot_table(data, values= ['  Female'], index= ['Education level'], columns= ['Wages'], aggfunc={ '  Female':np.mean,
                       '  Female':[ max,np.mean]})

# %%
pivM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries,       Above bachelor's degree to Total, all education levels
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   (  Male, Average hourly wage rate)  14 non-null     float64
#  1   (  Male, Average weekly wage rate)  14 non-null     float64
#  2   (  Male, Median hourly wage rate)   14 non-null     float64
#  3   (  Male, Median weekly wage rate)   14 non-null     float64
#  4   (  Male, Total employees)           14 non-null     float64
# dtypes: float64(5)
# memory usage: 672.0+ bytes

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=piv.reset_index(), x='Education level', y=piv.columns[0])
plt.title('Mean Wages by Education Level')
plt.xlabel('Education Level')
plt.xticks(rotation=90)
plt.ylabel('Mean Wages (in thousands)')
#plt.legend(title='Wages')
plt.show()
